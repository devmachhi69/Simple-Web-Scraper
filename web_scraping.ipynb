# %%
#install request package and import
import requests

# %%
a = requests.get("https://quotes.toscrape.com/page/10/")

# %%
for i in range(1,11):
    with open(f"html/page1{i}.html","w",encoding="utf-8") as f:
        f.write(a.text)
        print(f"downloaded page{i} successfully")
# Out:
# downloaded page1 successfully
# downloaded page2 successfully
# downloaded page3 successfully
# downloaded page4 successfully
# downloaded page5 successfully
# downloaded page6 successfully
# downloaded page7 successfully
# downloaded page8 successfully
# downloaded page9 successfully
# downloaded page10 successfully

# %%
print(a.status_code)
# Out:
# 200

# %%
#print(a.content)

# %%
print(a.headers)
# Out:
# {'Date': 'Thu, 20 Nov 2025 20:39:55 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '11064', 'Connection': 'keep-alive', 'Strict-Transport-Security': 'max-age=0; includeSubDomains; preload'}
